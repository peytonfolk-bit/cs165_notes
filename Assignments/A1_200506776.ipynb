# %% [markdown]
# # Question 1
# An interpreted language is a language that does not get compiled into an executable and doesn't give your code access to your hardware (i.e python), while a compiled language like a C++ file goes straight to memory and the compiler runs an executable file that can be executed on your computer.

# %% [markdown]
# # Question 2
# ## a.
# print("Hello World')
# The error here is that we have a double quotations at the start of expression and a single quotation at the end of the expression
# ## b.
# x = 42
# print(X)
# The error here is that capital "X" is not in defined, little x is defined as 42
# ## c.
# 2nd_x = "Hello World"
# print(2nd_x)
# The error here is that we can't have a variable with a number in it. Variables must be underscores or letters (upper or lowercase)
# ## d.
# print('hello' + ' ' + 'world')
# No error here, unless... the example is backticks which I don't it is
# ## e.
# 42 = a
# print(a)
# Error here is that you can't assign a literal number to a variable. The variable has to be on the left.
# ## f.
# print(4+2))
# Error here is that we have an unmatched parenthesis on the right.
# ## g.
# print (4 + 2 +* 42)
# Error here is the operand "+*" is invalid syntax.
# ## h.
# print('Alice' / 'Al')
# Error here is that the operand '/' is not supported for string types.
# ## i.
# x = 5
# print(x+=5)
# Error here is that '+=' is invalid syntax and not a valid operator.
# ## j.
# _v = 50
# print(_v == 42)
# No error

# %% [markdown]
# # Question 3
# ## a.
# result = (10 + 5) * 2
# ## b.
# result = (20 - 4) * 5 > 5 * 2 + 10
# ## c.
# result = (20 // (2 + 5)) ** 2
# ## d.
# result = True and not (False or True)

# %% [markdown]
# # Question 4
# ## a. What is the difference between a statement and an expression?
# A statement is a complete line of code that performs an action or task, each statement is executed sequentially. Conversely, an expression is what gets evaluated to produce a value.

# %%
result = True and not (False or True)
print(result)
# Out:
# False
